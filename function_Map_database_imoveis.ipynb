# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrade-Douglas/POWER-BI/blob/master/function_Map_database_imoveis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from numpy import random
from datetime import datetime
from google.colab import files
from IPython import display

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-1f8536be-c773-43b9-844e-d50c0ec2a5f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1f8536be-c773-43b9-844e-d50c0ec2a5f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Interface.jpg to Interface.jpg

# %%
display.Image("Interface.jpg")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
areas_imoveis = [32,50,70,90,100,150,200,250,300,350,400]
area_imovel = [random.choice(areas_imoveis) for i in range(1000)]

fatoImobiliaria = pd.DataFrame(data = area_imovel, columns=['area'])
fatoImobiliaria
# Out:
#      area
# 0     350
# 1      70
# 2     100
# 3      50
# 4      90
# ..    ...
# 995   150
# 996    70
# 997   400
# 998   150
# 999    32
#
# [1000 rows x 1 columns]

# %%
idades_imoveis = [[1,2,3], [1,2,3,4,5], [1,2,3,4], [1,2,3,4,5,6], [1,2,3,4], [3,4,5,6,7], [3,4,5,6]]

fatoImobiliaria['idade'] = list(map(lambda x:
                                random.choice(idades_imoveis[0]) if 32 >= x or x <= 90 else
                               (random.choice(idades_imoveis[1]) if x == 100 else
                                random.choice(idades_imoveis[2]) if 150 == x or x == 200 else
                                random.choice(idades_imoveis[3]) if x == 250 else
                                random.choice(idades_imoveis[4]) if x == 300 else
                                random.choice(idades_imoveis[5]) if x == 350 else
                                random.choice(idades_imoveis[6]) if x == 400 else 'Undefined'), fatoImobiliaria.area
                              )
                          )
fatoImobiliaria
# Out:
#      area  idade
# 0     350      6
# 1      70      2
# 2     100      1
# 3      50      3
# 4      90      2
# ..    ...    ...
# 995   150      2
# 996    70      2
# 997   400      5
# 998   150      4
# 999    32      3
#
# [1000 rows x 2 columns]

# %%
estados_imoveis = {'id_estado':[1,2,3,4,5,6], 
                  'estado':['Rio Grande do Sul','Santa Catarina','São Paulo','Rio de Janeiro','Minas Gerais','Bahia'],
                  'uf':['RS','SC','SP','RJ','MG','BA'],
                  'pais':['Brasil','Brasil','Brasil','Brasil','Brasil','Brasil']
                  }

dimEstado = pd.DataFrame(data = estados_imoveis)
dimEstado
# Out:
#    id_estado             estado  uf    pais
# 0          1  Rio Grande do Sul  RS  Brasil
# 1          2     Santa Catarina  SC  Brasil
# 2          3          São Paulo  SP  Brasil
# 3          4     Rio de Janeiro  RJ  Brasil
# 4          5       Minas Gerais  MG  Brasil
# 5          6              Bahia  BA  Brasil

# %%
dimEstado.to_excel(
    "/content/drive/My Drive/Cientista de Dados/Power BI/Corretora de Imóveis/bd/dimEstado.xls"
    )

# %%
#id_estado_imovel = [1,2,3,4,5,6]

fatoImobiliaria['estado_imovel'] = [random.choice(dimEstado.id_estado) for i in range(1000)]
fatoImobiliaria
# Out:
#      area  idade  estado_imovel
# 0     350      6              4
# 1      70      2              6
# 2     100      1              5
# 3      50      3              1
# 4      90      2              2
# ..    ...    ...            ...
# 995   150      2              6
# 996    70      2              5
# 997   400      5              6
# 998   150      4              4
# 999    32      3              3
#
# [1000 rows x 3 columns]

# %%
dormitorios_imoveis = [[1,2], [1,2], [2,3], [3,4], [4,5]]

fatoImobiliaria['dormitorio_imovel'] = list(map(lambda x: 
                                                          random.choice(dormitorios_imoveis[0]) if 32 >= x or x <= 70 else
                                                         (random.choice(dormitorios_imoveis[1]) if x == 90 else
                                                          random.choice(dormitorios_imoveis[2]) if 100 >= x or x <= 200 else
                                                          random.choice(dormitorios_imoveis[3]) if x == 250 else
                                                          random.choice(dormitorios_imoveis[4]) if 300 >= x or x <= 400 else 'Undefined'), fatoImobiliaria.area
                                                )
                                                             
                                            )
fatoImobiliaria
# Out:
#      area  idade  estado_imovel  dormitorio_imovel
# 0     350      6              4                  5
# 1      70      2              6                  1
# 2     100      1              5                  3
# 3      50      3              1                  2
# 4      90      2              2                  2
# ..    ...    ...            ...                ...
# 995   150      2              6                  2
# 996    70      2              5                  1
# 997   400      5              6                  4
# 998   150      4              4                  2
# 999    32      3              3                  1
#
# [1000 rows x 4 columns]

# %%
piscina_imovel = {'id_piscina_imovel':[0,1], 'piscina_imovel':['Não','Sim']}
dimPiscina = pd.DataFrame(data=piscina_imovel)
dimPiscina
# Out:
#    id_piscina_imovel piscina_imovel
# 0                  0            Não
# 1                  1            Sim

# %%
dimPiscina.to_excel(
    "/content/drive/My Drive/Cientista de Dados/Power BI/Corretora de Imóveis/bd/dimPiscina.xls"
    )

# %%
piscinas_imoveis = [[0,1], [1]]

fatoImobiliaria['piscina_imovel'] = list(map(lambda x:
                                             random.choice(piscinas_imoveis[0]) if 32 >= x or x <= 70 else
                                             (random.choice(piscinas_imoveis[1]) if 90 >= x or x <= 400 else 'Undefined'), fatoImobiliaria.area
                                             )
                                         )
fatoImobiliaria
# Out:
#      area  idade  estado_imovel  dormitorio_imovel  piscina_imovel
# 0     350      6              4                  5               1
# 1      70      2              6                  1               1
# 2     100      1              5                  3               1
# 3      50      3              1                  2               0
# 4      90      2              2                  2               1
# ..    ...    ...            ...                ...             ...
# 995   150      2              6                  2               1
# 996    70      2              5                  1               0
# 997   400      5              6                  4               1
# 998   150      4              4                  2               1
# 999    32      3              3                  1               0
#
# [1000 rows x 5 columns]

# %%
elevadores_imoveis = {'id_elevador_imovel':['0','1'], 'elevador_imovel':['Não','Sim']}
dimElevador = pd.DataFrame(data=elevadores_imoveis)
dimElevador
# Out:
#   id_elevador_imovel elevador_imovel
# 0                  0             Não
# 1                  1             Sim

# %%
dimElevador.to_excel(
    "/content/drive/My Drive/Cientista de Dados/Power BI/Corretora de Imóveis/bd/dimElevador.xls"
    )

# %%
elevadores_imoveis = [[0,1], [1]]

fatoImobiliaria['elevador_imovel'] = list(map(lambda x:
                                              random.choice(elevadores_imoveis[0]) if 32 >= x or x <= 70 else
                                             (random.choice(elevadores_imoveis[1]) if 90 >= x or x <= 400 else 'Undefined'), fatoImobiliaria.area
                                             )
                                         )

fatoImobiliaria
# Out:
#      area  idade  ...  piscina_imovel  elevador_imovel
# 0     350      6  ...               1                1
# 1      70      2  ...               1                1
# 2     100      1  ...               1                1
# 3      50      3  ...               0                0
# 4      90      2  ...               1                1
# ..    ...    ...  ...             ...              ...
# 995   150      2  ...               1                1
# 996    70      2  ...               0                0
# 997   400      5  ...               1                1
# 998   150      4  ...               1                1
# 999    32      3  ...               0                1
#
# [1000 rows x 6 columns]

# %%
garagens_imoveis = [[0,1], [1,2], [2,3], [3,4]]

fatoImobiliaria['garagem_imovel'] = list(map(lambda x:
                                              random.choice(garagens_imoveis[0]) if 32 >= x or x <= 70 else
                                             (random.choice(garagens_imoveis[1]) if 90 >= x or x <= 200 else
                                              random.choice(garagens_imoveis[2]) if x == 300 else
                                              random.choice(garagens_imoveis[3]) if 350 <= x or x <= 400 else 'Undefined'), fatoImobiliaria.area
                                             )
                                         )
fatoImobiliaria
# Out:
#      area  idade  ...  elevador_imovel  garagem_imovel
# 0     350      6  ...                1               4
# 1      70      2  ...                1               0
# 2     100      1  ...                1               1
# 3      50      3  ...                0               0
# 4      90      2  ...                1               1
# ..    ...    ...  ...              ...             ...
# 995   150      2  ...                1               2
# 996    70      2  ...                0               0
# 997   400      5  ...                1               4
# 998   150      4  ...                1               1
# 999    32      3  ...                1               0
#
# [1000 rows x 7 columns]

# %%
classe_bairro_imovel = {'id_classe_bairro_imovel':[1,2,3,4,5,6], 'classe_bairro_imovel':['A+','A','B','C','D','E']}
dimClasseBairro = pd.DataFrame(data=classe_bairro_imovel)
dimClasseBairro
# Out:
#    id_classe_bairro_imovel classe_bairro_imovel
# 0                        1                   A+
# 1                        2                    A
# 2                        3                    B
# 3                        4                    C
# 4                        5                    D
# 5                        6                    E

# %%
dimClasseBairro.to_excel(
    "/content/drive/My Drive/Cientista de Dados/Power BI/Corretora de Imóveis/bd/dimClasseBairro.xls"
    )

# %%
classes_bairros_imoveis = [['4','5','6'], ['3','4'], ['2','3'], ['1']]

fatoImobiliaria['classes_bairros'] = list(map(lambda x:
                                              random.choice(classes_bairros_imoveis[0]) if 32 >= x or x <= 70 else
                                             (random.choice(classes_bairros_imoveis[1]) if 90 >= x or x <= 100 else
                                              random.choice(classes_bairros_imoveis[2]) if 150 >= x or x <= 250 else
                                              random.choice(classes_bairros_imoveis[3]) if 300 <= x or x <= 400 else 'Undefined'), fatoImobiliaria.area
                                             )
                                         )
fatoImobiliaria
# Out:
#      area  idade  ...  garagem_imovel  classes_bairros
# 0     350      6  ...               4                1
# 1      70      2  ...               0                6
# 2     100      1  ...               1                3
# 3      50      3  ...               0                6
# 4      90      2  ...               1                3
# ..    ...    ...  ...             ...              ...
# 995   150      2  ...               2                2
# 996    70      2  ...               0                5
# 997   400      5  ...               4                1
# 998   150      4  ...               1                2
# 999    32      3  ...               0                4
#
# [1000 rows x 8 columns]

# %%
situacoes_imoveis = {'id_situação_imovel':[1,2,3,4], 'situação_imovel':['Alugado-Sim','Alugado-Não','Vendido-Sim','Vendido-Não']}
dimSituacao = pd.DataFrame(data = situacoes_imoveis)
dimSituacao
# Out:
#    id_situação_imovel situação_imovel
# 0                   1     Alugado-Sim
# 1                   2     Alugado-Não
# 2                   3     Vendido-Sim
# 3                   4     Vendido-Não

# %%
dimSituacao.to_excel(
    "/content/drive/My Drive/Cientista de Dados/Power BI/Corretora de Imóveis/bd/dimSituação.xls"
    )

# %%
situacoes_imoveis = [1,2,3,4]

fatoImobiliaria['situacao_imovel'] = [random.choice(situacoes_imoveis) for i in range(1000)]
fatoImobiliaria
# Out:
#      area  idade  ...  classes_bairros  situacao_imovel
# 0     350      6  ...                1                2
# 1      70      2  ...                6                2
# 2     100      1  ...                3                2
# 3      50      3  ...                6                3
# 4      90      2  ...                3                4
# ..    ...    ...  ...              ...              ...
# 995   150      2  ...                2                1
# 996    70      2  ...                5                1
# 997   400      5  ...                1                4
# 998   150      4  ...                2                2
# 999    32      3  ...                4                1
#
# [1000 rows x 9 columns]

# %%
idades = range(25,65)
fatoImobiliaria['idade_cliente'] = list(map(lambda x: random.choice(idades) if x == 1 or x == 3 else '', fatoImobiliaria.situacao_imovel))
fatoImobiliaria
# Out:
#      area  idade  estado_imovel  ...  classes_bairros  situacao_imovel  idade_cliente
# 0     350      6              4  ...                1                2
# 1      70      2              6  ...                6                2
# 2     100      1              5  ...                3                2
# 3      50      3              1  ...                6                3             45
# 4      90      2              2  ...                3                4
# ..    ...    ...            ...  ...              ...              ...            ...
# 995   150      2              6  ...                2                1             29
# 996    70      2              5  ...                5                1             41
# 997   400      5              6  ...                1                4
# 998   150      4              4  ...                2                2
# 999    32      3              3  ...                4                1             36
#
# [1000 rows x 10 columns]

# %%
fatoImobiliaria['data_registro'] = list(map(lambda x: random.choice(pd.date_range(start='1-1-2015', end='1-7-2020')) if x == 1 or x == 3 else '', fatoImobiliaria.situacao_imovel))
fatoImobiliaria
# Out:
#      area  idade  ...  idade_cliente                  data_registro
# 0     350      6  ...
# 1      70      2  ...
# 2     100      1  ...
# 3      50      3  ...             45  2019-01-28T00:00:00.000000000
# 4      90      2  ...
# ..    ...    ...  ...            ...                            ...
# 995   150      2  ...             29  2018-08-29T00:00:00.000000000
# 996    70      2  ...             41  2018-02-24T00:00:00.000000000
# 997   400      5  ...
# 998   150      4  ...
# 999    32      3  ...             36  2016-11-06T00:00:00.000000000
#
# [1000 rows x 11 columns]

# %%
area_32_50 = range(80000,150000)
area_70 = range(150000,220000)
area_90 = range(220000,350000)
area_100 = range(300000,450000)
area_150 = range(450000,600000)
area_200 = range(600000,750000)
area_250 = range(700000,900000)
area_300 = range(1000000,1500000)
area_350 = range(1600000,2000000)
area_400 = range(2500000,3000000)

fatoImobiliaria['valor_venda'] = list(map(lambda x: 
                                                          random.choice(area_32_50) if 32 >= x or x <= 50 else
                                                         (random.choice(area_70) if x == 70 else
                                                          random.choice(area_90) if x == 90  else
                                                          random.choice(area_100) if x == 100 else
                                                          random.choice(area_150) if x == 150 else
                                                          random.choice(area_200) if x == 200 else
                                                          random.choice(area_250) if x == 250 else
                                                          random.choice(area_300) if x == 300 else
                                                          random.choice(area_350) if x == 350 else
                                                          random.choice(area_400) if x == 400 else 'Undefined'), fatoImobiliaria.area
                                                )
                                                             
                                            )
fatoImobiliaria
# Out:
#      area  idade  ...                  data_registro  valor_venda
# 0     350      6  ...                                     1613712
# 1      70      2  ...                                      176379
# 2     100      1  ...                                      388476
# 3      50      3  ...  2019-01-28T00:00:00.000000000       104693
# 4      90      2  ...                                      317549
# ..    ...    ...  ...                            ...          ...
# 995   150      2  ...  2018-08-29T00:00:00.000000000       493709
# 996    70      2  ...  2018-02-24T00:00:00.000000000       210778
# 997   400      5  ...                                     2911761
# 998   150      4  ...                                      576696
# 999    32      3  ...  2016-11-06T00:00:00.000000000       141160
#
# [1000 rows x 12 columns]

# %%
area_32_50 = range(800,1500)
area_70 = range(1500,2200)
area_90 = range(2200,3500)
area_100 = range(3000,4500)
area_150 = range(4500,6000)
area_200 = range(6000,7500)
area_250 = range(7000,9000)
area_300 = range(10000,15000)
area_350 = range(16000,20000)
area_400 = range(25000,30000)

fatoImobiliaria['valor_aluguel'] = list(map(lambda x: 
                                                          random.choice(area_32_50) if 32 >= x or x <= 50 else
                                                         (random.choice(area_70) if x == 70 else
                                                          random.choice(area_90) if x == 90  else
                                                          random.choice(area_100) if x == 100 else
                                                          random.choice(area_150) if x == 150 else
                                                          random.choice(area_200) if x == 200 else
                                                          random.choice(area_250) if x == 250 else
                                                          random.choice(area_300) if x == 300 else
                                                          random.choice(area_350) if x == 350 else
                                                          random.choice(area_400) if x == 400 else 'Undefined'), fatoImobiliaria.area
                                                )
                                                             
                                            )
fatoImobiliaria
# Out:
#      area  idade  ...  valor_venda  valor_aluguel
# 0     350      6  ...      1613712          17041
# 1      70      2  ...       176379           1939
# 2     100      1  ...       388476           3641
# 3      50      3  ...       104693           1400
# 4      90      2  ...       317549           2335
# ..    ...    ...  ...          ...            ...
# 995   150      2  ...       493709           5425
# 996    70      2  ...       210778           1712
# 997   400      5  ...      2911761          29413
# 998   150      4  ...       576696           5363
# 999    32      3  ...       141160           1306
#
# [1000 rows x 13 columns]

# %%
fatoImobiliaria.to_excel("/content/drive/My Drive/Cientista de Dados/Power BI/Corretora de Imóveis/bd/fatoImobiliaria.xls")

# %% [markdown]
# # Fim
